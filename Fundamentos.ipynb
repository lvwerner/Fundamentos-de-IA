# %% [markdown]
# <a href="https://colab.research.google.com/github/lvwerner/Fundamentos-de-IA/blob/main/Fundamentos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Flamengo, 4x campeão da libertadores!")
var a = 5
var  b = 10
var soma = a + b
print(soma)
# Out:
#   File "/tmp/ipykernel_160/4064573814.py", line 2
#     var a = 5
#         ^
# SyntaxError: invalid syntax

# %% [markdown]
# ![Mercado-Flamengo-1280x720.png](
#
#
#
#
# )
